# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
from tqdm import tqdm

# %%
li_main = [i for i in range(0,67600)]

# %%
li_main.insert(0,'label')

# %%
f=open('MCI-CN.csv','a')
writer = csv.writer(f)
writer.writerow(li_main)

for folder in os.listdir("../../../data/train"):
    for items in tqdm(os.listdir("../../../data/train/" + folder)):
        li = []
        if folder == 'AD' :
              #li.append(0)
            break
        elif folder == 'MCI' :
            li.append(1)
        elif folder == 'CN' :
            li.append(2)
        img = plt.imread("../../../data/train/" + folder + '/' + items)       
        li.extend(list(img.flatten()))
        writer.writerow(li)
        
f.flush()
f.close()
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 971/971 [02:02<00:00,  7.94it/s]

# %%
data=pd.read_csv('MCI-CN.csv')
data.head()
# Out:
# C:\Users\SONAL BANSAL\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    label    0    1    2    3    4    5    6    7    8  ...    67590  67591  \
# 0  label    0    1    2    3    4    5    6    7    8  ...    67590  67591
# 1      2  255  255  255  255  255  255  254  253  254  ...      255    255
# 2      2  255  255  255  255  255  255  254  253  254  ...      255    255
# 3      2  255  255  255  255  255  255  254  253  254  ...      255    255
# 4      2  255  255  255  255  255  255  254  253  254  ...      255    255
#
#    67592  67593  67594  67595  67596  67597  67598  67599
# 0  67592  67593  67594  67595  67596  67597  67598  67599
# 1    255    255    255    255    255    255    255    255
# 2    255    255    255    255    255    255    255    255
# ...

# %%
len(data[data['label']==0])
# Out:
# 0

# %%
f=open('MCI-CN_val.csv','a')
writer = csv.writer(f)
writer.writerow(li_main)
for folder in os.listdir("../../../data/val"):
    for items in tqdm(os.listdir("../../../data/val/" + folder)):
        li = []
        if folder == 'AD' :
              #li.append(0)
            break
        elif folder == 'MCI' :
            li.append(1)
        elif folder == 'CN' :
            li.append(2)
        img = plt.imread("../../../data/val/" + folder + '/' + items)       
        li.extend(list(img.flatten()))
        writer.writerow(li)
f.flush()
f.close()
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 295/295 [00:57<00:00,  5.10it/s]

# %%
data_val=pd.read_csv('MCI-CN_val.csv')
data_val.head()
# Out:
#    label    0    1    2    3    4    5    6    7    8  ...    67590  67591  \
# 0      2  255  255  255  255  255  255  254  253  254  ...      255    255
# 1      2  255  255  255  255  255  255  254  253  254  ...      255    255
# 2      2  255  255  255  255  255  255  254  253  254  ...      255    255
# 3      2  255  255  255  255  255  255  254  253  254  ...      255    255
# 4      2  255  255  255  255  255  255  254  253  254  ...      255    255
#
#    67592  67593  67594  67595  67596  67597  67598  67599
# 0    255    255    255    255    255    255    255    255
# 1    255    255    255    255    255    255    255    255
# 2    255    255    255    255    255    255    255    255
# 3    255    255    255    255    255    255    255    255
# 4    255    255    255    255    255    255    255    255
#
# [5 rows x 67601 columns]
